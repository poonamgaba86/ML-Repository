# %%
from bs4 import BeautifulSoup
import urllib.request
import nltk

# %%
response=urllib.request.urlopen('http://php.net/')
html=response.read()
soup=BeautifulSoup(html,"html5lib")

# %%
txt=soup.get_text()
txt
# Out:
# "\n\n  \n  \n\n  PHP: Hypertext Preprocessor\n\n \n \n \n \n\n \n \n \n\n\n\n\n\n\n\n\n\n \n\n \n\n \n\n \n\n \n\n\n\n\n\n\n  \n    \n    \n    \n    \n      Downloads\n      Documentation\n      Get Involved\n      Help\n      \n        \n          \n        \n      \n    \n    \n      \n      \n    \n  \n  \n\n\nGetting Started\n\tIntroduction\n\tA simple tutorial\nLanguage Reference\n\tBasic syntax\n\tTypes\n\tVariables\n\tConstants\n\tExpressions\n\tOperators\n\tControl Structures\n\tFunctions\n\tClasses and Objects\n\tNamespaces\n\tErrors\n\tExceptions\n\tGenerators\n\tAttributes\n\tReferences Explained\n\tPredefined Variables\n\tPredefined Exceptions\n\tPredefined Interfaces and Classes\n\tContext options and parameters\n\tSupported Protocols and Wrappers\n\n\nSecurity\n\tIntroduction\n\tGeneral considerations\n\tInstalled as CGI binary\n\tInstalled as an Apache module\n\tSession Security\n\tFilesystem Security\n\tDatabase Security\n\tError Reporting\n\tUser Submitted Data\n\tHiding PHP\n\tKeeping Current\nFeatures\n\tHTTP authentication with PHP\n\tCookies\n\tSessions\n\tDealing with XForms\n\tHandling file uploads\n\tUsing remote files\n\tConnection handling\n\tPersistent Database Connections\n\tCommand line usage\n\tGarbage Collection\n\tDTrace Dynamic Tracing\n\n\nFunction Reference\n\tAffecting PHP's Behaviour\n\tAudio Formats Manipulation\n\tAuthentication Services\n\tCommand Line Specific Extensions\n\tCompression and Archive Extensions\n\tCryptography Extensions\n\tDatabase Extensions\n\tDate and Time Related Extensions\n\tFile System Related Extensions\n\tHuman Language and Character Encoding Support\n\tImage Processing and Generation\n\tMail Related Extensions\n\tMathematical Extensions\n\tNon-Text MIME Output\n\tProcess Control Extensions\n\tOther Basic Extensions\n\tOther Services\n\tSearch Engine Extensions\n\tServer Specific Extensions\n\tSession Extensions\n\tText Processing\n\tVariable and Type Related Extensions\n\tWeb Services\n\tWindows Only Extensions\n\tXML Manipulation\n\tGUI Extensions\n\n\nKeyboard Shortcuts?\nThis help\nj\nNext menu item\nk\nPrevious menu item\ng p\nPrevious man page\ng n\nNext man page\nG\nScroll to bottom\ng g\nScroll to top\ng h\nGoto homepage\ng s\nGoto search(current page)\n/\nFocus search box\n\n\n    \n         \n         \n   \n\n\n\n\n\n  \n      \n    \n      PHP is a popular general-purpose scripting language that is especially suited to web development.\n      Fast, flexible and pragmatic, PHP powers everything from your blog to the most popular websites in the world.\n    \n    \n      Download\n\n            8.0.2·Release Notes·Upgrading\n\n            7.4.15·Release Notes·Upgrading\n\n            7.3.27·Release Notes·Upgrading\n\n    \n    \n\n\n\n\n  \n\n  \n    04 Feb 2021\n    \n      PHP 8.0.2 Released!\n    \n  \n  \n    The PHP development team announces the immediate availability of PHP 8.0.2. This is a bug fix release.\n\nAll PHP 8.0 users are encouraged to upgrade to this version.\n\nFor source downloads of PHP 8.0.2 please visit our downloads page,\nWindows source and binaries can be found on windows.php.net/download/.\nThe list of changes is recorded in the ChangeLog.\n    \n  \n  \n\n  \n    04 Feb 2021\n    \n      PHP 7.4.15 Released!\n    \n  \n  \n    The PHP development team announces the immediate availability of PHP 7.4.15. This is a security release.\n\nAll PHP 7.4 users are encouraged to upgrade to this version.\n\nFor source downloads of PHP 7.4.15 please visit our downloads page,\nWindows source and binaries can be found on windows.php.net/download/.\nThe list of changes is recorded in the ChangeLog.\n    \n  \n  \n\n  \n    04 Feb 2021\n    \n      PHP 7.3.27 Released!\n    \n  \n  \n    The PHP development team announces the immediate availability of PHP 7.3.27. This is a security release.\n\n      All PHP 7.3 users are encouraged to upgrade to this version.\n\n      For source downloads of PHP 7.3.27 please visit our downloads page,\n      ...

# %%
txt[0]
# Out:
# '\n'

# %%
len(txt)
# Out:
# 20561

# %%
sentences = nltk.sent_tokenize(txt)

# %%
len(sentences)
# Out:
# 197

# %%
from nltk.stem import WordNetLemmatizer

# %%
wordnet=WordNetLemmatizer()

# %%
from nltk.corpus import stopwords
# Lemmatization
words_li=[]
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [wordnet.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    print(words)
    words_li.extend(words)
# Out:
# ['PHP', ':', 'Hypertext', 'Preprocessor', 'Downloads', 'Documentation', 'Get', 'Involved', 'Help', 'Getting', 'Started', 'Introduction', 'A', 'simple', 'tutorial', 'Language', 'Reference', 'Basic', 'syntax', 'Types', 'Variables', 'Constants', 'Expressions', 'Operators', 'Control', 'Structures', 'Functions', 'Classes', 'Objects', 'Namespaces', 'Errors', 'Exceptions', 'Generators', 'Attributes', 'References', 'Explained', 'Predefined', 'Variables', 'Predefined', 'Exceptions', 'Predefined', 'Interfaces', 'Classes', 'Context', 'option', 'parameter', 'Supported', 'Protocols', 'Wrappers', 'Security', 'Introduction', 'General', 'consideration', 'Installed', 'CGI', 'binary', 'Installed', 'Apache', 'module', 'Session', 'Security', 'Filesystem', 'Security', 'Database', 'Security', 'Error', 'Reporting', 'User', 'Submitted', 'Data', 'Hiding', 'PHP', 'Keeping', 'Current', 'Features', 'HTTP', 'authentication', 'PHP', 'Cookies', 'Sessions', 'Dealing', 'XForms', 'Handling', 'file', 'uploads', 'Using', 'remote', 'file', 'Connection', 'handling', 'Persistent', 'Database', 'Connections', 'Command', 'line', 'usage', 'Garbage', 'Collection', 'DTrace', 'Dynamic', 'Tracing', 'Function', 'Reference', 'Affecting', 'PHP', "'s", 'Behaviour', 'Audio', 'Formats', 'Manipulation', 'Authentication', 'Services', 'Command', 'Line', 'Specific', 'Extensions', 'Compression', 'Archive', 'Extensions', 'Cryptography', 'Extensions', 'Database', 'Extensions', 'Date', 'Time', 'Related', 'Extensions', 'File', 'System', 'Related', 'Extensions', 'Human', 'Language', 'Character', 'Encoding', 'Support', 'Image', 'Processing', 'Generation', 'Mail', 'Related', 'Extensions', 'Mathematical', 'Extensions', 'Non-Text', 'MIME', 'Output', 'Process', 'Control', 'Extensions', 'Other', 'Basic', 'Extensions', 'Other', 'Services', 'Search', 'Engine', 'Extensions', 'Server', 'Specific', 'Extensions', 'Session', 'Extensions', 'Text', 'Processing', 'Variable', 'Type', 'Related', 'Extensions', 'Web', 'Services', 'Windows', 'Only', 'Extensions', 'XML', 'Manipulation', 'GUI', 'Extensions', 'Keyboard', 'Shortcuts', '?']
# ['This', 'help', 'j', 'Next', 'menu', 'item', 'k', 'Previous', 'menu', 'item', 'g', 'p', 'Previous', 'man', 'page', 'g', 'n', 'Next', 'man', 'page', 'G', 'Scroll', 'bottom', 'g', 'g', 'Scroll', 'top', 'g', 'h', 'Goto', 'homepage', 'g', 'Goto', 'search', '(', 'current', 'page', ')', '/', 'Focus', 'search', 'box', 'PHP', 'popular', 'general-purpose', 'scripting', 'language', 'especially', 'suited', 'web', 'development', '.']
# ['Fast', ',', 'flexible', 'pragmatic', ',', 'PHP', 'power', 'everything', 'blog', 'popular', 'website', 'world', '.']
# ['Download', '8.0.2·Release', 'Notes·Upgrading', '7.4.15·Release', 'Notes·Upgrading', '7.3.27·Release', 'Notes·Upgrading', '04', 'Feb', '2021', 'PHP', '8.0.2', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '8.0.2', '.']
# ['This', 'bug', 'fix', 'release', '.']
# ['All', 'PHP', '8.0', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.2', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['04', 'Feb', '2021', 'PHP', '7.4.15', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.4.15', '.']
# ['This', 'security', 'release', '.']
# ['All', 'PHP', '7.4', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.4.15', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['04', 'Feb', '2021', 'PHP', '7.3.27', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.3.27', '.']
# ['This', 'security', 'release', '.']
# ['All', 'PHP', '7.3', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.3.27', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['07', 'Jan', '2021', 'PHP', '8.0.1', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '8.0.1', '.']
# ['This', 'bug', 'fix', 'release', '.']
# ['All', 'PHP', '8.0', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.1', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['07', 'Jan', '2021', 'PHP', '7.3.26', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.3.26', '.']
# ['This', 'security', 'release', '.']
# ['All', 'PHP', '7.3', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.3.26', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['07', 'Jan', '2021', 'PHP', '7.4.14', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.4.14', '.']
# ['This', 'security', 'release', '.']
# ['All', 'PHP', '7.4', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.4.14', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['26', 'Nov', '2020', 'PHP', '8.0.0', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '8.0.0', '.']
# ['This', 'release', 'mark', 'latest', 'major', 'release', 'PHP', 'language', '.']
# ['PHP', '8.0', 'come', 'numerous', 'improvement', 'new', 'feature', ':', 'Union', 'Types', 'Named', 'Arguments', 'Match', 'Expressions', 'Attributes', 'Constructor', 'Property', 'Promotion', 'Nullsafe', 'Operator', 'Weak', 'Maps', 'Just', 'In', 'Time', 'Compilation', 'And', 'much', 'much', '...', 'Take', 'look', 'PHP', '8.0', 'Announcement', 'Addendum', 'information', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.0', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['The', 'migration', 'guide', 'available', 'PHP', 'Manual', '.']
# ['Please', 'consult', 'detailed', 'list', 'new', 'feature', 'backward', 'incompatible', 'change', '.']
# ['Many', 'thanks', 'contributor', 'supporter', '!']
# ['26', 'Nov', '2020', 'PHP', '7.3.25', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.3.25', '.']
# ['This', 'bug', 'fix', 'release', '.']
# ['All', 'PHP', '7.3', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.3.25', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['26', 'Nov', '2020', 'PHP', '7.4.13', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.4.13', '.']
# ['This', 'bug', 'fix', 'release', '.']
# ['All', 'PHP', '7.4', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.4.13', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['19', 'Nov', '2020', 'PHP', '8.0.0', 'Release', 'Candidate', '5', 'available', 'testing', 'The', 'PHP', 'team', 'pleased', 'announce', 'eleventh', 'testing', 'release', 'PHP', '8.0.0', ',', 'Release', 'Candidate', '5', '.']
# ['This', 'extra', 'unplanned', 'release', ',', "'re", 'planning', 'adjust', 'GA', 'date', ',', 'however', ',', 'may', 'change', 'course', 'RC', 'cycle', '.']
# ['The', 'updated', 'release', 'schedule', ',', 'always', ',', 'found', 'PHP', 'Wiki', 'page', 'PHP', '8.0', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.0', 'Release', 'Candidate', '5', 'please', 'visit', 'download', 'page', '.']
# ['Please', 'carefully', 'test', 'version', 'report', 'issue', 'found', 'bug', 'reporting', 'system', '.']
# ['Please', 'DO', 'NOT', 'use', 'version', 'production', ',', 'early', 'test', 'version', '.']
# ['For', 'information', 'new', 'feature', 'change', ',', 'read', 'NEWS', 'file', ',', 'UPGRADING', 'file', 'complete', 'list', 'upgrading', 'note', '.']
# ['These', 'file', 'also', 'found', 'release', 'archive', '.']
# ['The', 'next', 'release', 'General', 'Availability', ',', 'planned', 'Nov', '26', '2020', '.']
# ['The', 'signature', 'release', 'found', 'manifest', 'QA', 'site', '.']
# ['Thank', 'helping', 'u', 'make', 'PHP', 'better', '.']
# ['12', 'Nov', '2020', 'PHP', '8.0.0', 'Release', 'Candidate', '4', 'available', 'testing', 'The', 'PHP', 'team', 'pleased', 'announce', 'tenth', 'testing', 'release', 'PHP', '8.0.0', ',', 'Release', 'Candidate', '4', '.']
# ['At', 'time', ',', "'re", 'planning', 'adjust', 'GA', 'date', ',', 'however', 'may', 'change', 'course', 'RC', 'cycle', '.']
# ['The', 'updated', 'release', 'schedule', ',', 'always', ',', 'found', 'PHP', 'Wiki', 'page', 'PHP', '8.0', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.0', 'Release', 'Candidate', '4', 'please', 'visit', 'download', 'page', '.']
# ['Please', 'carefully', 'test', 'version', 'report', 'issue', 'found', 'bug', 'reporting', 'system', '.']
# ['Please', 'DO', 'NOT', 'use', 'version', 'production', ',', 'early', 'test', 'version', '.']
# ['For', 'information', 'new', 'feature', 'change', ',', 'read', 'NEWS', 'file', ',', 'UPGRADING', 'file', 'complete', 'list', 'upgrading', 'note', '.']
# ['These', 'file', 'also', 'found', 'release', 'archive', '.']
# ['The', 'next', 'release', 'General', 'Availability', ',', 'planned', 'Nov', '26', '2020', '.']
# ['The', 'signature', 'release', 'found', 'manifest', 'QA', 'site', '.']
# ['Thank', 'helping', 'u', 'make', 'PHP', 'better', '.']
# ['29', 'Oct', '2020', 'PHP', '7.4.12', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.4.12', '.']
# ['This', 'bug', 'fix', 'release', '.']
# ['All', 'PHP', '7.4', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.4.12', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['29', 'Oct', '2020', 'PHP', '8.0.0', 'Release', 'Candidate', '3', 'available', 'testing', 'The', 'PHP', 'team', 'pleased', 'announce', 'tenth', 'testing', 'release', 'PHP', '8.0.0', ',', 'Release', 'Candidate', '3', '.']
# ['At', 'time', ',', "'re", 'planning', 'adjust', 'GA', 'date', ',', 'however', 'may', 'change', 'course', 'RC', 'cycle', '.']
# ['The', 'updated', 'release', 'schedule', ',', 'always', ',', 'found', 'PHP', 'Wiki', 'page', 'PHP', '8.0', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.0', 'Release', 'Candidate', '3', 'please', 'visit', 'download', 'page', '.']
# ['Please', 'carefully', 'test', 'version', 'report', 'issue', 'found', 'bug', 'reporting', 'system', '.']
# ['Please', 'DO', 'NOT', 'use', 'version', 'production', ',', 'early', 'test', 'version', '.']
# ['For', 'information', 'new', 'feature', 'change', ',', 'read', 'NEWS', 'file', ',', 'UPGRADING', 'file', 'complete', 'list', 'upgrading', 'note', '.']
# ['These', 'file', 'also', 'found', 'release', 'archive', '.']
# ['The', 'next', 'release', 'Release', 'Candidate', '4', ',', 'planned', 'Nov', '12', '2020', '.']
# ['The', 'signature', 'release', 'found', 'manifest', 'QA', 'site', '.']
# ['Thank', 'helping', 'u', 'make', 'PHP', 'better', '.']
# ['29', 'Oct', '2020', 'PHP', '7.3.24', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.3.24', '.']
# ['This', 'bug', 'fix', 'release', '.']
# ['All', 'PHP', '7.3', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.3.24', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['16', 'Oct', '2020', 'PHP', '8.0.0', 'Release', 'Candidate', '2', 'available', 'testing', 'The', 'PHP', 'team', 'pleased', 'announce', 'ninth', 'testing', 'release', 'PHP', '8.0.0', ',', 'Release', 'Candidate', '2', '.']
# ['At', 'time', ',', "'re", 'planning', 'adjust', 'GA', 'date', ',', 'however', 'may', 'change', 'course', 'RC', 'cycle', '.']
# ['The', 'updated', 'release', 'schedule', ',', 'always', ',', 'found', 'PHP', 'Wiki', 'page', 'PHP', '8.0', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.0', 'Release', 'Candidate', '2', 'please', 'visit', 'download', 'page', '.']
# ['Please', 'carefully', 'test', 'version', 'report', 'issue', 'found', 'bug', 'reporting', 'system', '.']
# ['Please', 'DO', 'NOT', 'use', 'version', 'production', ',', 'early', 'test', 'version', '.']
# ['For', 'information', 'new', 'feature', 'change', ',', 'read', 'NEWS', 'file', ',', 'UPGRADING', 'file', 'complete', 'list', 'upgrading', 'note', '.']
# ['These', 'file', 'also', 'found', 'release', 'archive', '.']
# ['The', 'next', 'release', 'Release', 'Candidate', '3', ',', 'planned', 'Oct', '29', '2020', '.']
# ['The', 'signature', 'release', 'found', 'manifest', 'QA', 'site', '.']
# ['Thank', 'helping', 'u', 'make', 'PHP', 'better', '.']
# ['01', 'Oct', '2020', 'PHP', '8.0.0', 'Release', 'Candidate', '1', 'available', 'testing', 'The', 'PHP', 'team', 'pleased', 'announce', 'eighth', 'testing', 'release', 'PHP', '8.0.0', ',', 'Release', 'Candidate', '1', '.']
# ['At', 'time', ',', "'re", 'planning', 'adjust', 'GA', 'date', ',', 'however', 'may', 'change', 'course', 'RC', 'cycle', '.']
# ['The', 'updated', 'release', 'schedule', ',', 'always', ',', 'found', 'PHP', 'Wiki', 'page', 'PHP', '8.0', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.0', 'Release', 'Candidate', '1', 'please', 'visit', 'download', 'page', '.']
# ['Please', 'carefully', 'test', 'version', 'report', 'issue', 'found', 'bug', 'reporting', 'system', '.']
# ['Please', 'DO', 'NOT', 'use', 'version', 'production', ',', 'early', 'test', 'version', '.']
# ['For', 'information', 'new', 'feature', 'change', ',', 'read', 'NEWS', 'file', ',', 'UPGRADING', 'file', 'complete', 'list', 'upgrading', 'note', '.']
# ['These', 'file', 'also', 'found', 'release', 'archive', '.']
# ['The', 'next', 'release', 'Release', 'Candidate', '2', ',', 'planned', 'Oct', '15', '2020', '.']
# ['The', 'signature', 'release', 'found', 'manifest', 'QA', 'site', '.']
# ['Thank', 'helping', 'u', 'make', 'PHP', 'better', '.']
# ['01', 'Oct', '2020', 'PHP', '7.3.23', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.3.23', '.']
# ['This', 'security', 'release', '.']
# ['All', 'PHP', '7.3', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.3.23', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['01', 'Oct', '2020', 'PHP', '7.4.11', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.4.11', '.']
# ['This', 'security', 'release', '.']
# ['All', 'PHP', '7.4', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.4.11', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['01', 'Oct', '2020', 'PHP', '7.2.34', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.2.34', '.']
# ['This', 'security', 'release', '.']
# ['All', 'PHP', '7.2', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.2.34', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['17', 'Sep', '2020', 'PHP', '8.0.0', 'Beta', '4', 'available', 'testing', 'The', 'PHP', 'team', 'pleased', 'announce', 'seventh', 'testing', 'release', 'PHP', '8.0.0', ',', 'Beta', '4', '.']
# ['This', 'point', 'release', 'cycle', 'would', 'normally', 'RC1', ',', 'however', "'re", 'still', 'finalizing', 'development', 'JIT', 'squaring', 'away', 'named', 'argument', ',', "'ve", 'opted', 'extra', 'beta', 'release', 'plan', 'start', 'RC', 'cycle', 'two', 'week', '.']
# ['At', 'time', ',', "'re", 'planning', 'adjust', 'GA', 'date', ',', 'however', 'may', 'change', 'course', 'RC', 'cycle', '.']
# ['The', 'updated', 'release', 'schedule', ',', 'always', ',', 'found', 'PHP', 'Wiki', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.0', 'Beta', '4', 'please', 'visit', 'download', 'page', '.']
# ['Please', 'carefully', 'test', 'version', 'report', 'issue', 'found', 'bug', 'reporting', 'system', '.']
# ['Please', 'DO', 'NOT', 'use', 'version', 'production', ',', 'early', 'test', 'version', '.']
# ['For', 'information', 'new', 'feature', 'change', ',', 'read', 'NEWS', 'file', ',', 'UPGRADING', 'file', 'complete', 'list', 'upgrading', 'note', '.']
# ['These', 'file', 'also', 'found', 'release', 'archive', '.']
# ['The', 'next', 'release', 'Release', 'Candidate', '1', ',', 'planned', 'Oct', '1', '2020', '.']
# ['The', 'signature', 'release', 'found', 'manifest', 'QA', 'site', '.']
# ['Thank', 'helping', 'u', 'make', 'PHP', 'better', '.']
# ['03', 'Sep', '2020', 'PHP', '8.0.0', 'Beta', '3', 'available', 'testing', 'The', 'PHP', 'team', 'pleased', 'announce', 'sixth', 'testing', 'release', 'PHP', '8.0.0', ',', 'Beta', '3', '.']
# ['This', 'continues', 'PHP', '8.0', 'release', 'cycle', ',', 'rough', 'outline', 'specified', 'PHP', 'Wiki', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.0', 'Beta', '3', 'please', 'visit', 'download', 'page', '.']
# ['Please', 'carefully', 'test', 'version', 'report', 'issue', 'found', 'bug', 'reporting', 'system', '.']
# ['Please', 'DO', 'NOT', 'use', 'version', 'production', ',', 'early', 'test', 'version', '.']
# ['For', 'information', 'new', 'feature', 'change', ',', 'read', 'NEWS', 'file', ',', 'UPGRADING', 'file', 'complete', 'list', 'upgrading', 'note', '.']
# ['These', 'file', 'also', 'found', 'release', 'archive', '.']
# ['The', 'next', 'release', 'Release', 'Candidate', '1', ',', 'planned', 'Sep', '17', '2020', '.']
# ['The', 'signature', 'release', 'found', 'manifest', 'QA', 'site', '.']
# ['Thank', 'helping', 'u', 'make', 'PHP', 'better', '.']
# ['03', 'Sep', '2020', 'PHP', '7.4.10', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.4.10', '.']
# ['This', 'bug', 'fix', 'release', '.']
# ['All', 'PHP', '7.4', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.4.10', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['03', 'Sep', '2020', 'PHP', '7.3.22', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.3.22', '.']
# ['This', 'bug', 'fix', 'release', '.']
# ['All', 'PHP', '7.3', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.3.22', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['21', 'Aug', '2020', 'PHP', '8.0.0beta2', 'Released', '!']
# ['The', 'PHP', 'team', 'pleased', 'announce', 'fifth', 'testing', 'release', 'PHP', '8.0.0', ',', 'Beta', '2', '.']
# ['This', 'continues', 'PHP', '8.0', 'release', 'cycle', ',', 'rough', 'outline', 'specified', 'PHP', 'Wiki', '.']
# ['For', 'source', 'downloads', 'PHP', '8.0.0', 'Beta', '2', 'please', 'visit', 'download', 'page', '.']
# ['Please', 'carefully', 'test', 'version', 'report', 'issue', 'found', 'bug', 'reporting', 'system', '.']
# ['Please', 'DO', 'NOT', 'use', 'version', 'production', ',', 'early', 'test', 'version', '.']
# ['For', 'information', 'new', 'feature', 'change', ',', 'read', 'NEWS', 'file', ',', 'UPGRADING', 'file', 'complete', 'list', 'upgrading', 'note', '.']
# ['These', 'file', 'also', 'found', 'release', 'archive', '.']
# ['The', 'next', 'release', 'Beta', '3', ',', 'planned', 'Sep', '3', '2020', '.']
# ['The', 'signature', 'release', 'found', 'manifest', 'QA', 'site', '.']
# ['Thank', 'helping', 'u', 'make', 'PHP', 'better', '.']
# ['06', 'Aug', '2020', 'PHP', '7.4.9', 'Released', '!']
# ['The', 'PHP', 'development', 'team', 'announces', 'immediate', 'availability', 'PHP', '7.4.9', '.']
# ['This', 'bug', 'fix', 'release', '.']
# ['All', 'PHP', '7.4', 'user', 'encouraged', 'upgrade', 'version', '.']
# ['For', 'source', 'downloads', 'PHP', '7.4.9', 'please', 'visit', 'downloads', 'page', ',', 'Windows', 'source', 'binary', 'found', 'windows.php.net/download/', '.']
# ['The', 'list', 'change', 'recorded', 'ChangeLog', '.']
# ['Older', 'News', 'Entries', 'Upcoming', 'conferencesInternational', 'PHP', 'Conference', 'Berlin', '2021PHPerKaigi', '2021', 'User', 'Group', 'Events', 'Special', 'Thanks', 'Social', 'medium', '@', 'official_php', 'Copyright', '©', '2001-2021', 'The', 'PHP', 'Group', 'My', 'PHP.net', 'Contact', 'Other', 'PHP.net', 'site', 'Privacy', 'policy']

# %%
words_li
# Out:
# ['PHP',
#  ':',
#  'Hypertext',
#  'Preprocessor',
#  'Downloads',
#  'Documentation',
#  'Get',
#  'Involved',
#  'Help',
#  'Getting',
#  'Started',
#  'Introduction',
#  'A',
#  'simple',
#  'tutorial',
#  'Language',
#  'Reference',
#  'Basic',
#  'syntax',
#  'Types',
#  'Variables',
#  'Constants',
#  'Expressions',
#  'Operators',
#  'Control',
#  'Structures',
#  'Functions',
#  'Classes',
#  'Objects',
#  'Namespaces',
#  'Errors',
#  'Exceptions',
#  'Generators',
#  'Attributes',
#  'References',
#  'Explained',
#  'Predefined',
#  'Variables',
#  'Predefined',
#  'Exceptions',
#  'Predefined',
#  'Interfaces',
#  'Classes',
#  'Context',
#  'option',
#  'parameter',
#  'Supported',
#  'Protocols',
#  'Wrappers',
#  'Security',
#  'Introduction',
#  'General',
#  'consideration',
#  'Installed',
#  'CGI',
#  'binary',
#  'Installed',
#  'Apache',
#  'module',
#  'Session',
#  'Security',
#  'Filesystem',
#  'Security',
#  'Database',
#  'Security',
#  'Error',
#  'Reporting',
#  'User',
#  'Submitted',
#  'Data',
#  'Hiding',
#  'PHP',
#  'Keeping',
#  'Current',
#  'Features',
#  'HTTP',
#  'authentication',
#  'PHP',
#  'Cookies',
#  'Sessions',
#  'Dealing',
#  'XForms',
#  'Handling',
#  'file',
#  'uploads',
#  'Using',
#  'remote',
#  'file',
#  'Connection',
#  'handling',
#  'Persistent',
#  'Database',
#  'Connections',
#  'Command',
#  'line',
#  'usage',
#  'Garbage',
#  'Collection',
#  'DTrace',
#  'Dynamic',
#  'Tracing',
#  'Function',
#  'Reference',
#  'Affecting',
#  'PHP',
#  "'s",
#  'Behaviour',
#  'Audio',
#  'Formats',
#  'Manipulation',
#  'Authentication',
#  'Services',
#  'Command',
#  'Line',
#  'Specific',
#  'Extensions',
#  'Compression',
#  'Archive',
#  'Extensions',
#  'Cryptography',
#  'Extensions',
#  'Database',
#  'Extensions',
#  'Date',
#  'Time',
#  'Related',
#  'Extensions',
#  'File',
#  'System',
#  'Related',
#  'Extensions',
#  'Human',
#  'Language',
#  'Character',
#  'Encoding',
#  'Support',
#  'Image',
#  'Processing',
#  'Generation',
#  'Mail',
#  'Related',
#  'Extensions',
#  'Mathematical',
#  'Extensions',
#  'Non-Text',
#  'MIME',
#  'Output',
#  'Process',
#  'Control',
#  'Extensions',
#  'Other',
#  'Basic',
#  'Extensions',
#  'Other',
#  'Services',
#  'Search',
#  'Engine',
#  'Extensions',
#  'Server',
#  'Specific',
#  'Extensions',
#  'Session',
#  'Extensions',
#  'Text',
#  'Processing',
#  'Variable',
#  'Type',
#  'Related',
#  'Extensions',
#  'Web',
#  'Services',
#  'Windows',
#  'Only',
#  'Extensions',
#  'XML',
#  'Manipulation',
#  'GUI',
#  'Extensions',
#  'Keyboard',
#  'Shortcuts',
#  '?',
#  'This',
#  'help',
#  'j',
#  'Next',
#  'menu',
#  'item',
#  'k',
#  'Previous',
#  'menu',
#  'item',
#  'g',
#  'p',
#  'Previous',
#  'man',
#  'page',
#  'g',
#  'n',
#  'Next',
#  'man',
#  'page',
#  'G',
#  'Scroll',
#  'bottom',
#  'g',
#  'g',
#  'Scroll',
#  'top',
#  'g',
#  'h',
#  'Goto',
#  'homepage',
#  'g',
#  'Goto',
#  'search',
#  '(',
#  'current',
#  'page',
#  ')',
#  '/',
#  'Focus',
#  'search',
#  'box',
#  'PHP',
#  'popular',
#  'general-purpose',
#  'scripting',
#  'language',
#  'especially',
#  'suited',
#  'web',
#  'development',
#  '.',
#  'Fast',
#  ',',
#  'flexible',
#  'pragmatic',
#  ',',
#  'PHP',
#  'power',
#  'everything',
#  'blog',
#  'popular',
#  'website',
#  'world',
#  '.',
#  'Download',
#  '8.0.2·Release',
#  'Notes·Upgrading',
#  '7.4.15·Release',
#  'Notes·Upgrading',
#  '7.3.27·Release',
#  'Notes·Upgrading',
#  '04',
#  'Feb',
#  '2021',
#  'PHP',
#  '8.0.2',
#  'Released',
#  '!',
#  'The',
#  'PHP',
#  'development',
#  'team',
#  'announces',
#  'immediate',
#  'availability',
#  'PHP',
#  '8.0.2',
#  '.',
#  'This',
#  'bug',
#  'fix',
#  'release',
#  '.',
#  'All',
#  'PHP',
#  '8.0',
#  'user',
#  'encouraged',
#  'upgrade',
#  'version',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '8.0.2',
#  'please',
#  'visit',
#  'downloads',
#  'page',
#  ',',
#  'Windows',
#  'source',
#  'binary',
#  'found',
#  'windows.php.net/download/',
#  '.',
#  'The',
#  'list',
#  'change',
#  'recorded',
#  'ChangeLog',
#  '.',
#  '04',
#  'Feb',
#  '2021',
#  'PHP',
#  '7.4.15',
#  'Released',
#  '!',
#  'The',
#  'PHP',
#  'development',
#  'team',
#  'announces',
#  'immediate',
#  'availability',
#  'PHP',
#  '7.4.15',
#  '.',
#  'This',
#  'security',
#  'release',
#  '.',
#  'All',
#  'PHP',
#  '7.4',
#  'user',
#  'encouraged',
#  'upgrade',
#  'version',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '7.4.15',
#  'please',
#  'visit',
#  'downloads',
#  'page',
#  ',',
#  'Windows',
#  'source',
#  'binary',
#  'found',
#  'windows.php.net/download/',
#  '.',
#  'The',
#  'list',
#  'change',
#  'recorded',
#  'ChangeLog',
#  '.',
#  '04',
#  'Feb',
#  '2021',
#  'PHP',
#  '7.3.27',
#  'Released',
#  '!',
#  'The',
#  'PHP',
#  'development',
#  'team',
#  'announces',
#  'immediate',
#  'availability',
#  'PHP',
#  '7.3.27',
#  '.',
#  'This',
#  'security',
#  'release',
#  '.',
#  'All',
#  'PHP',
#  '7.3',
#  'user',
#  'encouraged',
#  'upgrade',
#  'version',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '7.3.27',
#  'please',
#  'visit',
#  'downloads',
#  'page',
#  ',',
#  'Windows',
#  'source',
#  'binary',
#  'found',
#  'windows.php.net/download/',
#  '.',
#  'The',
#  'list',
#  'change',
#  'recorded',
#  'ChangeLog',
#  '.',
#  '07',
#  'Jan',
#  '2021',
#  'PHP',
#  '8.0.1',
#  'Released',
#  '!',
#  'The',
#  'PHP',
#  'development',
#  'team',
#  'announces',
#  'immediate',
#  'availability',
#  'PHP',
#  '8.0.1',
#  '.',
#  'This',
#  'bug',
#  'fix',
#  'release',
#  '.',
#  'All',
#  'PHP',
#  '8.0',
#  'user',
#  'encouraged',
#  'upgrade',
#  'version',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '8.0.1',
#  'please',
#  'visit',
#  'downloads',
#  'page',
#  ',',
#  'Windows',
#  'source',
#  'binary',
#  'found',
#  'windows.php.net/download/',
#  '.',
#  'The',
#  'list',
#  'change',
#  'recorded',
#  'ChangeLog',
#  '.',
#  '07',
#  'Jan',
#  '2021',
#  'PHP',
#  '7.3.26',
#  'Released',
#  '!',
#  'The',
#  'PHP',
#  'development',
#  'team',
#  'announces',
#  'immediate',
#  'availability',
#  'PHP',
#  '7.3.26',
#  '.',
#  'This',
#  'security',
#  'release',
#  '.',
#  'All',
#  'PHP',
#  '7.3',
#  'user',
#  'encouraged',
#  'upgrade',
#  'version',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '7.3.26',
#  'please',
#  'visit',
#  'downloads',
#  'page',
#  ',',
#  'Windows',
#  'source',
#  'binary',
#  'found',
#  'windows.php.net/download/',
#  '.',
#  'The',
#  'list',
#  'change',
#  'recorded',
#  'ChangeLog',
#  '.',
#  '07',
#  'Jan',
#  '2021',
#  'PHP',
#  '7.4.14',
#  'Released',
#  '!',
#  'The',
#  'PHP',
#  'development',
#  'team',
#  'announces',
#  'immediate',
#  'availability',
#  'PHP',
#  '7.4.14',
#  '.',
#  'This',
#  'security',
#  'release',
#  '.',
#  'All',
#  'PHP',
#  '7.4',
#  'user',
#  'encouraged',
#  'upgrade',
#  'version',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '7.4.14',
#  'please',
#  'visit',
#  'downloads',
#  'page',
#  ',',
#  'Windows',
#  'source',
#  'binary',
#  'found',
#  'windows.php.net/download/',
#  '.',
#  'The',
#  'list',
#  'change',
#  'recorded',
#  'ChangeLog',
#  '.',
#  '26',
#  'Nov',
#  '2020',
#  'PHP',
#  '8.0.0',
#  'Released',
#  '!',
#  'The',
#  'PHP',
#  'development',
#  'team',
#  'announces',
#  'immediate',
#  'availability',
#  'PHP',
#  '8.0.0',
#  '.',
#  'This',
#  'release',
#  'mark',
#  'latest',
#  'major',
#  'release',
#  'PHP',
#  'language',
#  '.',
#  'PHP',
#  '8.0',
#  'come',
#  'numerous',
#  'improvement',
#  'new',
#  'feature',
#  ':',
#  'Union',
#  'Types',
#  'Named',
#  'Arguments',
#  'Match',
#  'Expressions',
#  'Attributes',
#  'Constructor',
#  'Property',
#  'Promotion',
#  'Nullsafe',
#  'Operator',
#  'Weak',
#  'Maps',
#  'Just',
#  'In',
#  'Time',
#  'Compilation',
#  'And',
#  'much',
#  'much',
#  '...',
#  'Take',
#  'look',
#  'PHP',
#  '8.0',
#  'Announcement',
#  'Addendum',
#  'information',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '8.0.0',
#  'please',
#  'visit',
#  'downloads',
#  'page',
#  ',',
#  'Windows',
#  'source',
#  'binary',
#  'found',
#  'windows.php.net/download/',
#  '.',
#  'The',
#  'list',
#  'change',
#  'recorded',
#  'ChangeLog',
#  '.',
#  'The',
#  'migration',
#  'guide',
#  'available',
#  'PHP',
#  'Manual',
#  '.',
#  'Please',
#  'consult',
#  'detailed',
#  'list',
#  'new',
#  'feature',
#  'backward',
#  'incompatible',
#  'change',
#  '.',
#  'Many',
#  'thanks',
#  'contributor',
#  'supporter',
#  '!',
#  '26',
#  'Nov',
#  '2020',
#  'PHP',
#  '7.3.25',
#  'Released',
#  '!',
#  'The',
#  'PHP',
#  'development',
#  'team',
#  'announces',
#  'immediate',
#  'availability',
#  'PHP',
#  '7.3.25',
#  '.',
#  'This',
#  'bug',
#  'fix',
#  'release',
#  '.',
#  'All',
#  'PHP',
#  '7.3',
#  'user',
#  'encouraged',
#  'upgrade',
#  'version',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '7.3.25',
#  'please',
#  'visit',
#  'downloads',
#  'page',
#  ',',
#  'Windows',
#  'source',
#  'binary',
#  'found',
#  'windows.php.net/download/',
#  '.',
#  'The',
#  'list',
#  'change',
#  'recorded',
#  'ChangeLog',
#  '.',
#  '26',
#  'Nov',
#  '2020',
#  'PHP',
#  '7.4.13',
#  'Released',
#  '!',
#  'The',
#  'PHP',
#  'development',
#  'team',
#  'announces',
#  'immediate',
#  'availability',
#  'PHP',
#  '7.4.13',
#  '.',
#  'This',
#  'bug',
#  'fix',
#  'release',
#  '.',
#  'All',
#  'PHP',
#  '7.4',
#  'user',
#  'encouraged',
#  'upgrade',
#  'version',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '7.4.13',
#  'please',
#  'visit',
#  'downloads',
#  'page',
#  ',',
#  'Windows',
#  'source',
#  'binary',
#  'found',
#  'windows.php.net/download/',
#  '.',
#  'The',
#  'list',
#  'change',
#  'recorded',
#  'ChangeLog',
#  '.',
#  '19',
#  'Nov',
#  '2020',
#  'PHP',
#  '8.0.0',
#  'Release',
#  'Candidate',
#  '5',
#  'available',
#  'testing',
#  'The',
#  'PHP',
#  'team',
#  'pleased',
#  'announce',
#  'eleventh',
#  'testing',
#  'release',
#  'PHP',
#  '8.0.0',
#  ',',
#  'Release',
#  'Candidate',
#  '5',
#  '.',
#  'This',
#  'extra',
#  'unplanned',
#  'release',
#  ',',
#  "'re",
#  'planning',
#  'adjust',
#  'GA',
#  'date',
#  ',',
#  'however',
#  ',',
#  'may',
#  'change',
#  'course',
#  'RC',
#  'cycle',
#  '.',
#  'The',
#  'updated',
#  'release',
#  'schedule',
#  ',',
#  'always',
#  ',',
#  'found',
#  'PHP',
#  'Wiki',
#  'page',
#  'PHP',
#  '8.0',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '8.0.0',
#  'Release',
#  'Candidate',
#  '5',
#  'please',
#  'visit',
#  'download',
#  'page',
#  '.',
#  'Please',
#  'carefully',
#  'test',
#  'version',
#  'report',
#  'issue',
#  'found',
#  'bug',
#  'reporting',
#  'system',
#  '.',
#  'Please',
#  'DO',
#  'NOT',
#  'use',
#  'version',
#  'production',
#  ',',
#  'early',
#  'test',
#  'version',
#  '.',
#  'For',
#  'information',
#  'new',
#  'feature',
#  'change',
#  ',',
#  'read',
#  'NEWS',
#  'file',
#  ',',
#  'UPGRADING',
#  'file',
#  'complete',
#  'list',
#  'upgrading',
#  'note',
#  '.',
#  'These',
#  'file',
#  'also',
#  'found',
#  'release',
#  'archive',
#  '.',
#  'The',
#  'next',
#  'release',
#  'General',
#  'Availability',
#  ',',
#  'planned',
#  'Nov',
#  '26',
#  '2020',
#  '.',
#  'The',
#  'signature',
#  'release',
#  'found',
#  'manifest',
#  'QA',
#  'site',
#  '.',
#  'Thank',
#  'helping',
#  'u',
#  'make',
#  'PHP',
#  'better',
#  '.',
#  '12',
#  'Nov',
#  '2020',
#  'PHP',
#  '8.0.0',
#  'Release',
#  'Candidate',
#  '4',
#  'available',
#  'testing',
#  'The',
#  'PHP',
#  'team',
#  'pleased',
#  'announce',
#  'tenth',
#  'testing',
#  'release',
#  'PHP',
#  '8.0.0',
#  ',',
#  'Release',
#  'Candidate',
#  '4',
#  '.',
#  'At',
#  'time',
#  ',',
#  "'re",
#  'planning',
#  'adjust',
#  'GA',
#  'date',
#  ',',
#  'however',
#  'may',
#  'change',
#  'course',
#  'RC',
#  'cycle',
#  '.',
#  'The',
#  'updated',
#  'release',
#  'schedule',
#  ',',
#  'always',
#  ',',
#  'found',
#  'PHP',
#  'Wiki',
#  'page',
#  'PHP',
#  '8.0',
#  '.',
#  'For',
#  'source',
#  'downloads',
#  'PHP',
#  '8.0.0',
#  'Release',
#  'Candidate',
#  '4',
#  'please',
#  'visit',
#  'download',
#  'page',
#  '.',
#  'Please',
#  'carefully',
#  'test',
#  'version',
#  'report',
#  'issue',
#  'found',
#  'bug',
#  'reporting',
#  'system',
#  '.',
#  'Please',
#  'DO',
#  'NOT',
#  'use',
#  'version',
#  ...]

# %%
freq = nltk.FreqDist(words_li) 
for key,val in freq.items(): 
    print (str(key) + ':' + str(val))
# Out:
# PHP:151
# ::2
# Hypertext:1
# Preprocessor:1
# Downloads:1
# Documentation:1
# Get:1
# Involved:1
# Help:1
# Getting:1
# Started:1
# Introduction:2
# A:1
# simple:1
# tutorial:1
# Language:2
# Reference:2
# Basic:2
# syntax:1
# Types:2
# Variables:2
# Constants:1
# Expressions:2
# Operators:1
# Control:2
# Structures:1
# Functions:1
# Classes:2
# Objects:1
# Namespaces:1
# Errors:1
# Exceptions:2
# Generators:1
# Attributes:2
# References:1
# Explained:1
# Predefined:3
# Interfaces:1
# Context:1
# option:1
# parameter:1
# Supported:1
# Protocols:1
# Wrappers:1
# Security:4
# General:3
# consideration:1
# Installed:2
# CGI:1
# binary:18
# Apache:1
# module:1
# Session:2
# Filesystem:1
# Database:3
# Error:1
# Reporting:1
# User:2
# Submitted:1
# Data:1
# Hiding:1
# Keeping:1
# Current:1
# Features:1
# HTTP:1
# authentication:1
# Cookies:1
# Sessions:1
# Dealing:1
# XForms:1
# Handling:1
# file:26
# uploads:1
# Using:1
# remote:1
# Connection:1
# handling:1
# Persistent:1
# Connections:1
# Command:2
# line:1
# usage:1
# Garbage:1
# Collection:1
# DTrace:1
# Dynamic:1
# Tracing:1
# Function:1
# Affecting:1
# 's:1
# Behaviour:1
# Audio:1
# Formats:1
# Manipulation:2
# Authentication:1
# Services:3
# Line:1
# Specific:2
# Extensions:16
# Compression:1
# Archive:1
# Cryptography:1
# Date:1
# Time:2
# Related:4
# File:1
# System:1
# Human:1
# Character:1
# Encoding:1
# Support:1
# Image:1
# Processing:2
# Generation:1
# Mail:1
# Mathematical:1
# Non-Text:1
# MIME:1
# Output:1
# Process:1
# Other:3
# Search:1
# Engine:1
# Server:1
# Text:1
# Variable:1
# Type:1
# Web:1
# Windows:18
# Only:1
# XML:1
# GUI:1
# Keyboard:1
# Shortcuts:1
# ?:1
# This:22
# help:1
# j:1
# Next:2
# menu:2
# item:2
# k:1
# Previous:2
# g:6
# p:1
# man:2
# page:33
# n:1
# G:1
# Scroll:2
# bottom:1
# top:1
# h:1
# Goto:2
# homepage:1
# search:2
# (:1
# current:1
# ):1
# /:1
# Focus:1
# box:1
# popular:2
# general-purpose:1
# scripting:1
# language:2
# especially:1
# suited:1
# web:1
# development:19
# .:176
# Fast:1
# ,:88
# flexible:1
# pragmatic:1
# power:1
# everything:1
# blog:1
# website:1
# world:1
# Download:1
# 8.0.2·Release:1
# Notes·Upgrading:3
# 7.4.15·Release:1
# 7.3.27·Release:1
# 04:3
# Feb:3
# 2021:7
# 8.0.2:3
# Released:18
# !:19
# The:66
# team:25
# announces:17
# immediate:17
# availability:17
# bug:17
# fix:9
# release:61
# All:16
# 8.0:11
# user:16
# encouraged:16
# upgrade:16
# version:40
# For:33
# source:42
# downloads:42
# please:25
# visit:25
# found:47
# windows.php.net/download/:17
# list:26
# change:32
# recorded:17
# ChangeLog:17
# 7.4.15:3
# security:7
# 7.4:7
# 7.3.27:3
# 7.3:6
# 07:3
# Jan:3
# 8.0.1:3
# 7.3.26:3
# 7.4.14:3
# 26:5
# Nov:8
# 2020:27
# 8.0.0:26
# mark:1
# latest:1
# major:1
# come:1
# numerous:1
# improvement:1
# new:10
# feature:10
# Union:1
# Named:1
# Arguments:1
# Match:1
# Constructor:1
# Property:1
# Promotion:1
# Nullsafe:1
# Operator:1
# Weak:1
# Maps:1
# Just:1
# In:1
# Compilation:1
# And:1
# much:2
# ...:1
# Take:1
# look:1
# Announcement:1
# Addendum:1
# information:9
# migration:1
# guide:1
# available:8
# Manual:1
# Please:17
# consult:1
# detailed:1
# backward:1
# incompatible:1
# Many:1
# thanks:1
# contributor:1
# supporter:1
# 7.3.25:3
# 7.4.13:3
# 19:1
# Release:20
# Candidate:20
# 5:3
# testing:15
# pleased:8
# announce:8
# eleventh:1
# extra:2
# unplanned:1
# 're:7
# planning:6
# adjust:6
# GA:6
# date:6
# however:7
# may:6
# course:6
# RC:7
# cycle:10
# updated:6
# schedule:6
# always:6
# Wiki:8
# download:8
# carefully:8
# test:16
# report:8
# issue:8
# reporting:8
# system:8
# DO:8
# NOT:8
# use:8
# production:8
# early:8
# read:8
# NEWS:8
# UPGRADING:8
# complete:8
# upgrading:8
# note:8
# These:8
# also:8
# archive:8
# next:8
# Availability:2
# planned:8
# signature:8
# manifest:8
# QA:8
# site:9
# Thank:8
# helping:8
# u:8
# make:8
# better:8
# 12:2
# 4:7
# tenth:2
# At:5
# time:5
# 29:4
# Oct:11
# 7.4.12:3
# 3:9
# 7.3.24:3
# 16:1
# 2:6
# ninth:1
# 01:4
# 1:6
# eighth:1
# 15:1
# 7.3.23:3
# 7.4.11:3
# 7.2.34:3
# 7.2:1
# 17:2
# Sep:6
# Beta:9
# seventh:1
# point:1
# would:1
# normally:1
# RC1:1
# still:1
# finalizing:1
# JIT:1
# squaring:1
# away:1
# named:1
# argument:1
# 've:1
# opted:1
# beta:1
# plan:1
# start:1
# two:1
# week:1
# 03:3
# sixth:1
# continues:2
# rough:2
# outline:2
# specified:2
# 7.4.10:3
# 7.3.22:3
# 21:1
# Aug:2
# 8.0.0beta2:1
# fifth:1
# 06:1
# 7.4.9:3
# Older:1
# News:1
# Entries:1
# Upcoming:1
# conferencesInternational:1
# Conference:1
# Berlin:1
# 2021PHPerKaigi:1
# Group:2
# Events:1
# Special:1
# Thanks:1
# Social:1
# medium:1
# @:1
# official_php:1
# Copyright:1
# ©:1
# 2001-2021:1
# My:1
# PHP.net:2
# Contact:1
# Privacy:1
# policy:1
